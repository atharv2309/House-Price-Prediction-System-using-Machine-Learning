# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
print("ML Mini Project House Price Prediction")
print("Atharv A Swarge | A218")
print("Aditya R Joshi | A207")
data
# Out:
# ML Mini Project House Price Prediction
# Atharv A Swarge | A218
# Aditya R Joshi | A207
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# ...

# %%
print("Atharv A Swarge | A218")
print("Aditya R Joshi | A207")
data.info()
# Out:
# Atharv A Swarge | A218
# Aditya R Joshi | A207
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
print("Atharv A Swarge | A218")
print("Aditya R Joshi | A207")
data.dropna()
# Out:
# Atharv A Swarge | A218
# Aditya R Joshi | A207
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
print("Atharv A Swarge | A218")
print("Aditya R Joshi | A207")
data.dropna(inplace=True)
# Out:
# Atharv A Swarge | A218
# Aditya R Joshi | A207

# %%
print("Atharv A Swarge | A218")
print("Aditya R Joshi | A207")
data.info()
# Out:
# Atharv A Swarge | A218
# Aditya R Joshi | A207
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
print("Atharv A Swarge | A218")
print("Aditya R Joshi | A207")
from sklearn.model_selection import train_test_split
X = data.drop(['median_house_value'], axis=1)
Y = data['median_house_value']
# Out:
# Atharv A Swarge | A218
# Aditya R Joshi | A207

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
print("Atharv A Swarge | A218")
print("Aditya R Joshi | A207")
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2)
# Out:
# Atharv A Swarge | A218
# Aditya R Joshi | A207

# %%
train_data = X_train.join(Y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19877    -119.25     36.36                16.0       3245.0           469.0
# 15698    -122.46     37.79                52.0        899.0            96.0
# 3447     -118.42     34.24                17.0       2049.0           548.0
# 10947    -117.87     33.76                 6.0       2992.0          1194.0
# 11673    -118.03     33.84                30.0       4781.0           831.0
# ...          ...       ...                 ...          ...             ...
# 18706    -122.37     40.54                28.0       2213.0           390.0
# 8977     -118.42     34.01                42.0       1700.0           438.0
# 19760    -122.25     40.15                15.0       1677.0           346.0
# 4550     -118.23     34.05                52.0        346.0           270.0
# 13906    -116.47     34.07                22.0       5473.0          1234.0
#
# ...

# %%
print("Atharv A Swarge | A218")
print("Aditya R Joshi | A207")
train_data.hist(figsize=(15,8))
# Out:
# Atharv A Swarge | A218
# Aditya R Joshi | A207
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
print("Atharv A Swarge | A218")
print("Aditya R Joshi | A207")
train_data.corr()
# Out:
# Atharv A Swarge | A218
# Aditya R Joshi | A207
# C:\Users\Atharv\AppData\Local\Temp\ipykernel_15640\3029174912.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train_data.corr()
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924749           -0.114010     0.046109
# latitude            -0.924749  1.000000            0.015765    -0.035192
# housing_median_age  -0.114010  0.015765            1.000000    -0.358121
# total_rooms          0.046109 -0.035192           -0.358121     1.000000
# total_bedrooms       0.070314 -0.065171           -0.317006     0.929448
# population           0.105290 -0.111966           -0.300794     0.863184
# households           0.056464 -0.069653           -0.299578     0.917540
# ...

# %%
print("Atharv A Swarge | A218")
print("Aditya R Joshi | A207")
sns.heatmap(train_data.corr(), annot=True, cmap = "YlGnBu")
plt.figure(figsize=(15,8))
# Out:
# Atharv A Swarge | A218
# Aditya R Joshi | A207
# C:\Users\Atharv\AppData\Local\Temp\ipykernel_15640\3552995516.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train_data.corr(), annot=True, cmap = "YlGnBu")

# %%
print("Atharv A Swarge | A218")
print("Aditya R Joshi | A207")
train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)
train_data['population'] = np.log(train_data['population'] + 1)
train_data['households'] = np.log(train_data['households'] + 1)
# Out:
# Atharv A Swarge | A218
# Aditya R Joshi | A207

# %%
print("Atharv A Swarge | A218")
print("Aditya R Joshi | A207")
train_data.hist(figsize=(15,8))
# Out:
# Atharv A Swarge | A218
# Aditya R Joshi | A207
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
print("Atharv A Swarge | A218")
print("Aditya R Joshi | A207")
train_data.ocean_proximity.value_counts()
# Out:
# Atharv A Swarge | A218
# Aditya R Joshi | A207
# <1H OCEAN     7214
# INLAND        5178
# NEAR OCEAN    2104
# NEAR BAY      1845
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
print("Atharv A Swarge | A218")
print("Aditya R Joshi | A207")
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'], axis = 1)
# Out:
# Atharv A Swarge | A218
# Aditya R Joshi | A207

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19877    -119.25     36.36                16.0     8.085179        6.152733
# 15698    -122.46     37.79                52.0     6.802395        4.574711
# 3447     -118.42     34.24                17.0     7.625595        6.308098
# 10947    -117.87     33.76                 6.0     8.004032        7.085901
# 11673    -118.03     33.84                30.0     8.472614        6.723832
# ...          ...       ...                 ...          ...             ...
# 18706    -122.37     40.54                28.0     7.702556        5.968708
# 8977     -118.42     34.01                42.0     7.438972        6.084499
# 19760    -122.25     40.15                15.0     7.425358        5.849325
# 4550     -118.23     34.05                52.0     5.849325        5.602119
# 13906    -116.47     34.07                22.0     8.607765        7.118826
#
# ...

# %%
print("Atharv A Swarge | A218")
print("Aditya R Joshi | A207")
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True,cmap="YlGnBu")
# Out:
# Atharv A Swarge | A218
# Aditya R Joshi | A207
# <Axes: >

# %%
print("Atharv A Swarge | A218")
print("Aditya R Joshi | A207")
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude",y="longitude",data=train_data,hue="median_house_value",palette="coolwarm")
# Out:
# Atharv A Swarge | A218
# Aditya R Joshi | A207
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
print("Atharv A Swarge | A218")
print("Aditya R Joshi | A207")

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train, Y_train = train_data.drop(['median_house_value'], axis =1), train_data['median_house_value']
X_train_s = scaler.fit_transform(X_train)

reg = LinearRegression()

reg.fit(X_train,Y_train)
# Out:
# Atharv A Swarge | A218
# Aditya R Joshi | A207
# LinearRegression()

# %%
print("Atharv A Swarge | A218")
print("Aditya R Joshi | A207")

test_data = X_test.join(Y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'], axis = 1)

test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms'] / test_data['households']
# Out:
# Atharv A Swarge | A218
# Aditya R Joshi | A207

# %%
reg.score(X_train_s,Y_train)
# Out:
# c:\Users\Atharv\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# -461.95211884444694

# %%
print("Atharv A Swarge | A218")
print("Aditya R Joshi | A207")

from sklearn.ensemble import RandomForestRegressor


forest = RandomForestRegressor()

forest.fit(X_train_s,Y_train)
# Out:
# Atharv A Swarge | A218
# Aditya R Joshi | A207
# RandomForestRegressor()

# %%
print("Atharv A Swarge | A218")
print("Aditya R Joshi | A207")

forest.score(X_test_s,Y_train)
# Out:
# Atharv A Swarge | A218
# Aditya R Joshi | A207
# 0.9746948991770661

# %%
print("Atharv A Swarge | A218")
print("Aditya R Joshi | A207")

from sklearn.model_selection import GridSearchCV
forest = RandomForestRegressor()

param_grid = {
    "n_estimators":[3,10,30],
    "max_features":[2,4,6,8]
}

grid_search = GridSearchCV(forest,param_grid,cv=5,
                           scoring="neg_mean_squared_error",
                           return_train_score=True)
grid_search.fit(X_train_s,Y_train)
# Out:
# Atharv A Swarge | A218
# Aditya R Joshi | A207
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [2, 4, 6, 8],
#                          'n_estimators': [3, 10, 30]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
print("Atharv A Swarge | A218")
print("Aditya R Joshi | A207")

grid_search.best_estimator_
# Out:
# Atharv A Swarge | A218
# Aditya R Joshi | A207
# RandomForestRegressor(max_features=6, n_estimators=30)

# %%
best_forest = grid_search.best_estimator_

# %%
print("Atharv A Swarge | A218")
print("Aditya R Joshi | A207")

best_forest.score(X_train_s,Y_train)
# Out:
# Atharv A Swarge | A218
# Aditya R Joshi | A207
# 0.9724225016296606

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(max_features=6, n_estimators=30)

# %%
print("Atharv A Swarge | A218")
print("Aditya R Joshi | A207")

grid_search.best_estimator_.score(X_train_s,Y_train)
# Out:
# Atharv A Swarge | A218
# Aditya R Joshi | A207
# 0.9724225016296606
